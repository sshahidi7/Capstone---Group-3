# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('db3.csv')
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
# 1               No    Petrol             3  192000 km          6
# 2               No    Petrol           1.3  200000 km          4
# 3              Yes    Hybrid           2.5  168966 km          4
# 4              Yes    Petrol           1.3   91901 km          4
#
#   Gear box type Drive wheels  Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  4-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  4-May        Left wheel   Black        8
# 2      Variator        Front  4-May  Right-hand drive   Black        2
# 3     Automatic          4x4  4-May        Left wheel   White        0
# 4     Automatic        Front  4-May        Left wheel  Silver        4

# %%
df.drop(columns='ID',inplace=True)

# %%
df.head()
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467     -        HONDA      FIT        2006  Hatchback               No
# 3   3607   862         FORD   Escape        2011       Jeep              Yes
# 4  11726   446        HONDA      FIT        2014  Hatchback              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km          6     Automatic          4x4
# 1    Petrol             3  192000 km          6     Tiptronic          4x4
# 2    Petrol           1.3  200000 km          4      Variator        Front
# 3    Hybrid           2.5  168966 km          4     Automatic          4x4
# 4    Petrol           1.3   91901 km          4     Automatic        Front
#
#    Doors             Wheel   Color  Airbags
# 0  4-May        Left wheel  Silver       12
# 1  4-May        Left wheel   Black        8
# 2  4-May  Right-hand drive   Black        2
# 3  4-May        Left wheel   White        0
# 4  4-May        Left wheel  Silver        4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             19237 non-null  int64
#  1   Levy              19237 non-null  object
#  2   Manufacturer      19237 non-null  object
#  3   Model             19237 non-null  object
#  4   Prod. year        19237 non-null  int64
#  5   Category          19237 non-null  object
#  6   Leather interior  19237 non-null  object
#  7   Fuel type         19237 non-null  object
#  8   Engine volume     19237 non-null  object
#  9   Mileage           19237 non-null  object
#  10  Cylinders         19237 non-null  int64
#  11  Gear box type     19237 non-null  object
#  12  Drive wheels      19237 non-null  object
#  13  Doors             19237 non-null  object
#  14  Wheel             19237 non-null  object
#  15  Color             19237 non-null  object
#  16  Airbags           19237 non-null  int64
# dtypes: int64(4), object(13)
# memory usage: 2.5+ MB

# %%
df['Levy'].value_counts()
# Out:
# -        5819
# 765       486
# 891       461
# 639       410
# 640       405
#          ...
# 4860        1
# 676         1
# 822         1
# 1572        1
# 11706       1
# Name: Levy, Length: 559, dtype: int64

# %%
df['Levy'].replace(to_replace='-',value=0,inplace=True)

# %%
df['Levy'] = df['Levy'].astype('float64')

# %%
pd.DataFrame(df['Manufacturer'].str.upper().value_counts())
# Out:
#                Manufacturer
# HYUNDAI                3769
# TOYOTA                 3662
# MERCEDES-BENZ          2076
# FORD                   1111
# CHEVROLET              1069
# ...                     ...
# TESLA                     1
# LAMBORGHINI               1
# PONTIAC                   1
# GREATWALL                 1
# LANCIA                    1
#
# [65 rows x 1 columns]

# %%
pd.DataFrame(df['Manufacturer'].str.upper().value_counts()).sort_values('Manufacturer').head(40)
# Out:
#               Manufacturer
# LANCIA                   1
# HAVAL                    1
# ASTON MARTIN             1
# SATURN                   1
# GREATWALL                1
# LAMBORGHINI              1
# PONTIAC                  1
# TESLA                    1
# SEAT                     2
# FERRARI                  2
# ᲡᲮᲕᲐ                     2
# BENTLEY                  2
# ROLLS-ROYCE              2
# ZAZ                      2
# SAAB                     2
# ROVER                    3
# MASERATI                 4
# ISUZU                    4
# MOSKVICH                 4
# ALFA ROMEO               4
# MERCURY                  4
# HUMMER                   5
# SCION                    7
# CITROEN                  9
# UAZ                     12
# GAZ                     12
# DAIHATSU                13
# CADILLAC                14
# LINCOLN                 15
# ACURA                   15
# GMC                     15
# BUICK                   16
# PEUGEOT                 17
# VOLVO                   19
# SKODA                   20
# CHRYSLER                26
# INFINITI                30
# RENAULT                 37
# JAGUAR                  42
# VAZ                     48

# %%
pd.DataFrame(df['Model'].str.upper().value_counts())
# Out:
#                   Model
# PRIUS              1083
# SONATA             1079
# CAMRY               938
# ELANTRA             922
# E 350               542
# ...                 ...
# TRANSIT 350T          1
# GLC 250               1
# A4 PREMIUM PLIUS      1
# S 430 4.3             1
# SORENTO EX            1
#
# [1511 rows x 1 columns]

# %%
df['Prod. year'].value_counts()
# Out:
# 2012    2155
# 2014    2124
# 2013    1963
# 2011    1612
# 2015    1549
# 2010    1483
# 2016    1476
# 2017     959
# 2008     737
# 2009     601
# 2018     500
# 2007     464
# 2005     402
# 2003     367
# 2004     364
# 2006     317
# 2019     306
# 2002     296
# 2000     279
# 2001     254
# 1998     213
# 1999     207
# 1997     151
# 1996     114
# 1995     105
# 2020      47
# 1994      42
# 1992      30
# 1993      23
# 1990      18
# 1988      12
# 1991      10
# 1989       6
# 1986       6
# 1984       5
# 1985       5
# 1987       5
# 1953       4
# 1983       3
# 1939       3
# 1974       2
# 1965       2
# 1980       2
# 1964       2
# 1978       2
# 1977       2
# 1947       1
# 1981       1
# 1976       1
# 1943       1
# 1982       1
# 1957       1
# 1973       1
# 1968       1
# Name: Prod. year, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Sedan          8736
# Jeep           5473
# Hatchback      2847
# Minivan         647
# Coupe           532
# Universal       364
# Microbus        306
# Goods wagon     233
# Pickup           52
# Cabriolet        36
# Limousine        11
# Name: Category, dtype: int64

# %%
df['Leather interior'].value_counts()
# Out:
# Yes    13954
# No      5283
# Name: Leather interior, dtype: int64

# %%
df['Fuel type'].value_counts()
# Out:
# Petrol            10150
# Diesel             4036
# Hybrid             3578
# LPG                 892
# CNG                 494
# Plug-in Hybrid       86
# Hydrogen              1
# Name: Fuel type, dtype: int64

# %%
df['Engine volume'].value_counts()
# Out:
# 2            3916
# 2.5          2277
# 1.8          1760
# 1.6          1462
# 1.5          1321
#              ...
# 6.8             1
# 0.5             1
# 5.8             1
# 0.4 Turbo       1
# 5.7 Turbo       1
# Name: Engine volume, Length: 107, dtype: int64

# %%
volume = df['Engine volume'].apply(lambda x : x.split(' ')[0]).astype('float64')
aspiration = df['Engine volume'].apply(lambda x : x.split(' ')[1] if len(x.split(' '))>1 else 'Natural')

# %%
volume.value_counts()
# Out:
# 2.0    4324
# 2.5    2370
# 1.8    1937
# 1.6    1578
# 1.5    1393
#        ...
# 6.8       1
# 0.5       1
# 5.8       1
# 7.3       1
# 3.1       1
# Name: Engine volume, Length: 65, dtype: int64

# %%
aspiration.value_counts()
# Out:
# Natural    17306
# Turbo       1931
# Name: Engine volume, dtype: int64

# %%
df.drop(df.columns[[8]], axis=1, inplace=True)

# %%
df.insert(8,'Engine volume',volume,allow_duplicates=True)
df.insert(9,'Aspiration',aspiration)

# %%
df
# Out:
#        Price    Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399.0          LEXUS   RX 450        2010       Jeep
# 1      16621  1018.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467     0.0          HONDA      FIT        2006  Hatchback
# 3       3607   862.0           FORD   Escape        2011       Jeep
# 4      11726   446.0          HONDA      FIT        2014  Hatchback
# ...      ...     ...            ...      ...         ...        ...
# 19232   8467     0.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831.0        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836.0        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288.0      CHEVROLET  Captiva        2007       Jeep
# 19236    470   753.0        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type  Engine volume Aspiration    Mileage  \
# 0                  Yes    Hybrid            3.5    Natural  186005 km
# 1                   No    Petrol            3.0    Natural  192000 km
# 2                   No    Petrol            1.3    Natural  200000 km
# 3                  Yes    Hybrid            2.5    Natural  168966 km
# 4                  Yes    Petrol            1.3    Natural   91901 km
# ...                ...       ...            ...        ...        ...
# 19232              Yes       CNG            2.0      Turbo  300000 km
# 19233              Yes    Petrol            2.4    Natural  161600 km
# 19234              Yes    Diesel            2.0    Natural  116365 km
# 19235              Yes    Diesel            2.0    Natural   51258 km
# 19236              Yes    Hybrid            2.4    Natural  186923 km
#
#        Cylinders Gear box type Drive wheels  Doors             Wheel   Color  \
# 0              6     Automatic          4x4  4-May        Left wheel  Silver
# 1              6     Tiptronic          4x4  4-May        Left wheel   Black
# 2              4      Variator        Front  4-May  Right-hand drive   Black
# 3              4     Automatic          4x4  4-May        Left wheel   White
# 4              4     Automatic        Front  4-May        Left wheel  Silver
# ...          ...           ...          ...    ...               ...     ...
# 19232          4        Manual         Rear  2-Mar        Left wheel  Silver
# 19233          4     Tiptronic        Front  4-May        Left wheel     Red
# 19234          4     Automatic        Front  4-May        Left wheel    Grey
# 19235          4     Automatic        Front  4-May        Left wheel   Black
# 19236          4     Automatic        Front  4-May        Left wheel   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19237 rows x 18 columns]

# %%
df['Mileage'] = df['Mileage'].apply(lambda x: x[:-3]).astype(float)

# %%
df
# Out:
#        Price    Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399.0          LEXUS   RX 450        2010       Jeep
# 1      16621  1018.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467     0.0          HONDA      FIT        2006  Hatchback
# 3       3607   862.0           FORD   Escape        2011       Jeep
# 4      11726   446.0          HONDA      FIT        2014  Hatchback
# ...      ...     ...            ...      ...         ...        ...
# 19232   8467     0.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831.0        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836.0        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288.0      CHEVROLET  Captiva        2007       Jeep
# 19236    470   753.0        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type  Engine volume Aspiration   Mileage  \
# 0                  Yes    Hybrid            3.5    Natural  186005.0
# 1                   No    Petrol            3.0    Natural  192000.0
# 2                   No    Petrol            1.3    Natural  200000.0
# 3                  Yes    Hybrid            2.5    Natural  168966.0
# 4                  Yes    Petrol            1.3    Natural   91901.0
# ...                ...       ...            ...        ...       ...
# 19232              Yes       CNG            2.0      Turbo  300000.0
# 19233              Yes    Petrol            2.4    Natural  161600.0
# 19234              Yes    Diesel            2.0    Natural  116365.0
# 19235              Yes    Diesel            2.0    Natural   51258.0
# 19236              Yes    Hybrid            2.4    Natural  186923.0
#
#        Cylinders Gear box type Drive wheels  Doors             Wheel   Color  \
# 0              6     Automatic          4x4  4-May        Left wheel  Silver
# 1              6     Tiptronic          4x4  4-May        Left wheel   Black
# 2              4      Variator        Front  4-May  Right-hand drive   Black
# 3              4     Automatic          4x4  4-May        Left wheel   White
# 4              4     Automatic        Front  4-May        Left wheel  Silver
# ...          ...           ...          ...    ...               ...     ...
# 19232          4        Manual         Rear  2-Mar        Left wheel  Silver
# 19233          4     Tiptronic        Front  4-May        Left wheel     Red
# 19234          4     Automatic        Front  4-May        Left wheel    Grey
# 19235          4     Automatic        Front  4-May        Left wheel   Black
# 19236          4     Automatic        Front  4-May        Left wheel   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19237 rows x 18 columns]

# %%
df['Doors'].value_counts()
# Out:
# 4-May    18332
# 2-Mar      777
# >5         128
# Name: Doors, dtype: int64

# %%
df.replace(to_replace='4-May',value="4",inplace=True)
df.replace(to_replace='2-Mar',value="2",inplace=True)
df.replace(to_replace='>5',value="5 or more",inplace=True)

# %%
df
# Out:
#        Price    Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399.0          LEXUS   RX 450        2010       Jeep
# 1      16621  1018.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467     0.0          HONDA      FIT        2006  Hatchback
# 3       3607   862.0           FORD   Escape        2011       Jeep
# 4      11726   446.0          HONDA      FIT        2014  Hatchback
# ...      ...     ...            ...      ...         ...        ...
# 19232   8467     0.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831.0        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836.0        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288.0      CHEVROLET  Captiva        2007       Jeep
# 19236    470   753.0        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type  Engine volume Aspiration   Mileage  \
# 0                  Yes    Hybrid            3.5    Natural  186005.0
# 1                   No    Petrol            3.0    Natural  192000.0
# 2                   No    Petrol            1.3    Natural  200000.0
# 3                  Yes    Hybrid            2.5    Natural  168966.0
# 4                  Yes    Petrol            1.3    Natural   91901.0
# ...                ...       ...            ...        ...       ...
# 19232              Yes       CNG            2.0      Turbo  300000.0
# 19233              Yes    Petrol            2.4    Natural  161600.0
# 19234              Yes    Diesel            2.0    Natural  116365.0
# 19235              Yes    Diesel            2.0    Natural   51258.0
# 19236              Yes    Hybrid            2.4    Natural  186923.0
#
#        Cylinders Gear box type Drive wheels Doors             Wheel   Color  \
# 0              6     Automatic          4x4     4        Left wheel  Silver
# 1              6     Tiptronic          4x4     4        Left wheel   Black
# 2              4      Variator        Front     4  Right-hand drive   Black
# 3              4     Automatic          4x4     4        Left wheel   White
# 4              4     Automatic        Front     4        Left wheel  Silver
# ...          ...           ...          ...   ...               ...     ...
# 19232          4        Manual         Rear     2        Left wheel  Silver
# 19233          4     Tiptronic        Front     4        Left wheel     Red
# 19234          4     Automatic        Front     4        Left wheel    Grey
# 19235          4     Automatic        Front     4        Left wheel   Black
# 19236          4     Automatic        Front     4        Left wheel   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19237 rows x 18 columns]

# %%
df['Doors'].value_counts()
# Out:
# 4            18332
# 2              777
# 5 or more      128
# Name: Doors, dtype: int64

# %%
df.Wheel.value_counts()
# Out:
# Left wheel          17753
# Right-hand drive     1484
# Name: Wheel, dtype: int64

# %%
df.Color.value_counts()
# Out:
# Black            5033
# White            4489
# Silver           3792
# Grey             2375
# Blue             1396
# Red               639
# Green             322
# Orange            253
# Brown             187
# Carnelian red     179
# Golden            145
# Beige             134
# Sky blue          122
# Yellow            106
# Purple             39
# Pink               26
# Name: Color, dtype: int64

# %%
df.Airbags.value_counts()
# Out:
# 4     5823
# 12    5654
# 0     2405
# 8     1608
# 6     1311
# 2     1066
# 10     849
# 5      104
# 16      93
# 7       86
# 1       76
# 9       63
# 3       37
# 11      33
# 14      20
# 15       7
# 13       2
# Name: Airbags, dtype: int64

# %%
df
# Out:
#        Price    Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399.0          LEXUS   RX 450        2010       Jeep
# 1      16621  1018.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467     0.0          HONDA      FIT        2006  Hatchback
# 3       3607   862.0           FORD   Escape        2011       Jeep
# 4      11726   446.0          HONDA      FIT        2014  Hatchback
# ...      ...     ...            ...      ...         ...        ...
# 19232   8467     0.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831.0        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836.0        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288.0      CHEVROLET  Captiva        2007       Jeep
# 19236    470   753.0        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type  Engine volume Aspiration   Mileage  \
# 0                  Yes    Hybrid            3.5    Natural  186005.0
# 1                   No    Petrol            3.0    Natural  192000.0
# 2                   No    Petrol            1.3    Natural  200000.0
# 3                  Yes    Hybrid            2.5    Natural  168966.0
# 4                  Yes    Petrol            1.3    Natural   91901.0
# ...                ...       ...            ...        ...       ...
# 19232              Yes       CNG            2.0      Turbo  300000.0
# 19233              Yes    Petrol            2.4    Natural  161600.0
# 19234              Yes    Diesel            2.0    Natural  116365.0
# 19235              Yes    Diesel            2.0    Natural   51258.0
# 19236              Yes    Hybrid            2.4    Natural  186923.0
#
#        Cylinders Gear box type Drive wheels Doors             Wheel   Color  \
# 0              6     Automatic          4x4     4        Left wheel  Silver
# 1              6     Tiptronic          4x4     4        Left wheel   Black
# 2              4      Variator        Front     4  Right-hand drive   Black
# 3              4     Automatic          4x4     4        Left wheel   White
# 4              4     Automatic        Front     4        Left wheel  Silver
# ...          ...           ...          ...   ...               ...     ...
# 19232          4        Manual         Rear     2        Left wheel  Silver
# 19233          4     Tiptronic        Front     4        Left wheel     Red
# 19234          4     Automatic        Front     4        Left wheel    Grey
# 19235          4     Automatic        Front     4        Left wheel   Black
# 19236          4     Automatic        Front     4        Left wheel   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19237 rows x 18 columns]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)
import seaborn as sns

# To display all columns of a table
pd.set_option('display.max_columns', None)

# %%
plt.title('Car Price Spread')
sns.boxplot(y=df.Price)
plt.show()
print(df.Price.describe())
# Out:
# count    1.923700e+04
# mean     1.855593e+04
# std      1.905813e+05
# min      1.000000e+00
# 25%      5.331000e+03
# 50%      1.317200e+04
# 75%      2.207500e+04
# max      2.630750e+07
# Name: Price, dtype: float64

# %%
df[df['Price']>250000]
# Out:
#           Price    Levy   Manufacturer                    Model  Prod. year  \
# 1225     627220     0.0  MERCEDES-BENZ           G 65 AMG 63AMG        2020
# 5008     308906  1694.0        PORSCHE                      911        2016
# 5840     254024  1292.0  MERCEDES-BENZ            GLE 400 A M G        2016
# 7749     288521  2269.0            BMW  M5 Машина в максимально        2018
# 8541     872946  2067.0    LAMBORGHINI                     Urus        2019
# 9367     297930     0.0  MERCEDES-BENZ                 AMG GT S        2015
# 10759    260296     0.0          LEXUS                   LX 570        2018
# 14839    297930     0.0     LAND ROVER        Range Rover Vogue        2019
# 15283    250574  1481.0  MERCEDES-BENZ                  GLE 400        2017
# 16983  26307500     0.0           OPEL                    Combo        1999
#
#           Category Leather interior Fuel type  Engine volume Aspiration  \
# 1225          Jeep              Yes    Petrol            6.3      Turbo
# 5008         Coupe              Yes    Petrol            4.0    Natural
# 5840          Jeep              Yes    Petrol            3.0      Turbo
# 7749         Sedan              Yes    Petrol            4.4    Natural
# 8541     Universal              Yes    Petrol            4.0    Natural
# 9367         Coupe              Yes    Petrol            4.0      Turbo
# 10759         Jeep              Yes    Petrol            5.7      Turbo
# 14839         Jeep              Yes    Diesel            3.0      Turbo
# 15283         Jeep              Yes    Petrol            3.0      Turbo
# 16983  Goods wagon               No    Diesel            1.7    Natural
#
#        Mileage  Cylinders Gear box type Drive wheels Doors       Wheel  Color  \
# 1225       0.0          8     Tiptronic          4x4     4  Left wheel  Black
# 5008    8690.0          6     Automatic         Rear     2  Left wheel  Black
# 5840   73000.0          6     Tiptronic          4x4     4  Left wheel  Black
# 7749   13500.0          8     Tiptronic          4x4     4  Left wheel  Black
# 8541    2531.0          8     Tiptronic          4x4     4  Left wheel  Black
# 9367   20000.0          8     Tiptronic         Rear     2  Left wheel  White
# 10759  17700.0          8     Tiptronic          4x4     4  Left wheel  Black
# 14839   4500.0          8     Tiptronic          4x4     4  Left wheel  Black
# 15283  81600.0          6     Tiptronic          4x4     4  Left wheel  Black
# 16983  99999.0          4        Manual        Front     2  Left wheel   Blue
#
#        Airbags
# 1225        12
# 5008        12
# 5840        12
# 7749         0
# 8541         0
# 9367        16
# 10759       10
# 14839       12
# 15283       12
# 16983        0

# %% [markdown]
# There is an evident outlier: OPEL Combo is a non-luxury, everyday work vehicle that couldn't reach a price of 26 millions, so we'll drop that entry.

# %%
to_drop = df[df['Price']>400000].index

# %%
df.drop(index=to_drop,inplace=True)

# %%
plt.title('Car Price Spread')
sns.boxplot(y=df.Price)
plt.show()
print(df.Price.describe())
# Out:
# count     19234.000000
# mean      17113.065717
# std       18278.647663
# min           1.000000
# 25%        5331.000000
# 50%       13172.000000
# 75%       22063.000000
# max      308906.000000
# Name: Price, dtype: float64

# %%
df[df['Price']<5000].hist(bins=50);

# %%
df[df.Price<1000].sort_values('Mileage')
# Out:
#        Price    Levy Manufacturer   Model  Prod. year   Category  \
# 6938      80     0.0       TOYOTA   Camry        2014      Sedan
# 3377      30     0.0        HONDA     FIT        2010  Hatchback
# 6779     392  1086.0     CADILLAC     SRX        2012       Jeep
# 6801     706   751.0      HYUNDAI  Sonata        2013      Sedan
# 16404    706   751.0      HYUNDAI  Sonata        2013      Sedan
# ...      ...     ...          ...     ...         ...        ...
# 8486      40     0.0        HONDA     FIT        2006  Hatchback
# 18673     40     0.0        HONDA     FIT        2007  Hatchback
# 8695     941     0.0     MOSKVICH    2140        1985      Sedan
# 9524      50     0.0       TOYOTA   Prius        2011  Hatchback
# 15347      3     0.0          BMW     525        1995      Sedan
#
#       Leather interior Fuel type  Engine volume Aspiration       Mileage  \
# 6938                No    Hybrid            2.4    Natural  0.000000e+00
# 3377                No    Petrol            1.3    Natural  0.000000e+00
# 6779               Yes    Petrol            3.6    Natural  0.000000e+00
# 6801               Yes    Hybrid            2.4    Natural  0.000000e+00
# 16404              Yes    Hybrid            2.4    Natural  0.000000e+00
# ...                ...       ...            ...        ...           ...
# 8486               Yes    Petrol            1.3    Natural  1.111111e+07
# 18673              Yes    Petrol            1.6    Natural  1.500000e+07
# 8695                No    Petrol            1.5    Natural  2.000000e+07
# 9524                No    Hybrid            1.8    Natural  1.111111e+09
# 15347               No    Petrol            2.8    Natural  2.147484e+09
#
#        Cylinders Gear box type Drive wheels Doors             Wheel     Color  \
# 6938           6     Automatic        Front     4        Left wheel     Black
# 3377           4     Automatic        Front     4  Right-hand drive     White
# 6779           6     Automatic          4x4     4        Left wheel     Black
# 6801           4     Automatic        Front     4        Left wheel     White
# 16404          4     Automatic        Front     4        Left wheel     White
# ...          ...           ...          ...   ...               ...       ...
# 8486           4      Variator        Front     4  Right-hand drive     White
# 18673          7     Automatic        Front     4        Left wheel  Sky blue
# 8695           4        Manual         Rear     4        Left wheel       Red
# 9524           4     Automatic        Front     4        Left wheel     White
# 15347          6        Manual         Rear     4        Left wheel     Black
#
#        Airbags
# 6938         6
# 3377         4
# 6779        12
# 6801         0
# 16404        0
# ...        ...
# 8486         4
# 18673        9
# 8695         0
# 9524         6
# 15347        3
#
# [2574 rows x 18 columns]

# %%
df
# Out:
#        Price    Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399.0          LEXUS   RX 450        2010       Jeep
# 1      16621  1018.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467     0.0          HONDA      FIT        2006  Hatchback
# 3       3607   862.0           FORD   Escape        2011       Jeep
# 4      11726   446.0          HONDA      FIT        2014  Hatchback
# ...      ...     ...            ...      ...         ...        ...
# 19232   8467     0.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831.0        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836.0        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288.0      CHEVROLET  Captiva        2007       Jeep
# 19236    470   753.0        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type  Engine volume Aspiration   Mileage  \
# 0                  Yes    Hybrid            3.5    Natural  186005.0
# 1                   No    Petrol            3.0    Natural  192000.0
# 2                   No    Petrol            1.3    Natural  200000.0
# 3                  Yes    Hybrid            2.5    Natural  168966.0
# 4                  Yes    Petrol            1.3    Natural   91901.0
# ...                ...       ...            ...        ...       ...
# 19232              Yes       CNG            2.0      Turbo  300000.0
# 19233              Yes    Petrol            2.4    Natural  161600.0
# 19234              Yes    Diesel            2.0    Natural  116365.0
# 19235              Yes    Diesel            2.0    Natural   51258.0
# 19236              Yes    Hybrid            2.4    Natural  186923.0
#
#        Cylinders Gear box type Drive wheels Doors             Wheel   Color  \
# 0              6     Automatic          4x4     4        Left wheel  Silver
# 1              6     Tiptronic          4x4     4        Left wheel   Black
# 2              4      Variator        Front     4  Right-hand drive   Black
# 3              4     Automatic          4x4     4        Left wheel   White
# 4              4     Automatic        Front     4        Left wheel  Silver
# ...          ...           ...          ...   ...               ...     ...
# 19232          4        Manual         Rear     2        Left wheel  Silver
# 19233          4     Tiptronic        Front     4        Left wheel     Red
# 19234          4     Automatic        Front     4        Left wheel    Grey
# 19235          4     Automatic        Front     4        Left wheel   Black
# 19236          4     Automatic        Front     4        Left wheel   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19234 rows x 18 columns]

# %%
low_price_cars_indeces = df[df.Price<1000].index
Non_low_price_cars = df.drop(index=low_price_cars_indeces)
Non_low_price_cars
# Out:
#        Price    Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399.0          LEXUS   RX 450        2010       Jeep
# 1      16621  1018.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467     0.0          HONDA      FIT        2006  Hatchback
# 3       3607   862.0           FORD   Escape        2011       Jeep
# 4      11726   446.0          HONDA      FIT        2014  Hatchback
# ...      ...     ...            ...      ...         ...        ...
# 19231   5802  1055.0  MERCEDES-BENZ    E 350        2013      Sedan
# 19232   8467     0.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831.0        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836.0        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288.0      CHEVROLET  Captiva        2007       Jeep
#
#       Leather interior Fuel type  Engine volume Aspiration   Mileage  \
# 0                  Yes    Hybrid            3.5    Natural  186005.0
# 1                   No    Petrol            3.0    Natural  192000.0
# 2                   No    Petrol            1.3    Natural  200000.0
# 3                  Yes    Hybrid            2.5    Natural  168966.0
# 4                  Yes    Petrol            1.3    Natural   91901.0
# ...                ...       ...            ...        ...       ...
# 19231              Yes    Diesel            3.5    Natural  107800.0
# 19232              Yes       CNG            2.0      Turbo  300000.0
# 19233              Yes    Petrol            2.4    Natural  161600.0
# 19234              Yes    Diesel            2.0    Natural  116365.0
# 19235              Yes    Diesel            2.0    Natural   51258.0
#
#        Cylinders Gear box type Drive wheels Doors             Wheel   Color  \
# 0              6     Automatic          4x4     4        Left wheel  Silver
# 1              6     Tiptronic          4x4     4        Left wheel   Black
# 2              4      Variator        Front     4  Right-hand drive   Black
# 3              4     Automatic          4x4     4        Left wheel   White
# 4              4     Automatic        Front     4        Left wheel  Silver
# ...          ...           ...          ...   ...               ...     ...
# 19231          6     Automatic         Rear     4        Left wheel    Grey
# 19232          4        Manual         Rear     2        Left wheel  Silver
# 19233          4     Tiptronic        Front     4        Left wheel     Red
# 19234          4     Automatic        Front     4        Left wheel    Grey
# 19235          4     Automatic        Front     4        Left wheel   Black
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19231       12
# 19232        5
# 19233        8
# 19234        4
# 19235        4
#
# [16660 rows x 18 columns]

# %% [markdown]
# #### The Guinness World Record for the highest vehicle mileage on a personal car is 3.2 million miles or over 5 million kilometers, so we'll drop any car with mileage higher than 1 millon kilometers (cars with higher mileage are very rare to find)

# %%
Non_low_price_cars[Non_low_price_cars['Mileage']>5000000]
# Out:
#        Price    Levy   Manufacturer     Model  Prod. year     Category  \
# 985     2700     0.0           OPEL    Vectra        1997        Sedan
# 1146   13485     0.0            BMW       525        2003        Sedan
# 1404    9095     0.0            BMW       328        2002        Sedan
# 1892    7213     0.0  MERCEDES-BENZ     C 180        1997        Sedan
# 2278    6899     0.0     VOLKSWAGEN      Golf        1999        Sedan
# 2512   15681     0.0            BMW        X5        2005         Jeep
# 4823    3000     0.0            UAZ     31514        1991        Coupe
# 5456   12544     0.0         NISSAN   X-Terra        2004         Jeep
# 6157    5959     0.0  MERCEDES-BENZ     C 180        1995        Sedan
# 7000   15053     0.0  MERCEDES-BENZ  Sprinter        1998     Microbus
# 7429    6272     0.0  MERCEDES-BENZ      Vito        1999      Minivan
# 7724    4800     0.0           OPEL     Corsa        1999        Sedan
# 8824    5018     0.0     MITSUBISHI      Colt        2002        Sedan
# 8858    5500     0.0           FORD   Transit        1991     Microbus
# 9330    1568     0.0         TOYOTA      VOXY        2003      Minivan
# 9542    8467     0.0         SUBARU    Legacy        2004        Sedan
# 10667   6476     0.0         NISSAN      Note        2008    Hatchback
# 11144   6272     0.0  MERCEDES-BENZ     C 180        1995        Sedan
# 11266  11917     0.0           FORD   Transit        1996     Microbus
# 11430   3800     0.0          MAZDA   Protege        2001        Sedan
# 11472   2300     0.0         SUZUKI     Swift        2005    Hatchback
# 11901  10036     0.0         SUBARU  Forester        2005         Jeep
# 12591   2600  1529.0           OPEL    Vectra        1995        Sedan
# 12734   2200     0.0            UAZ     31514        1968         Jeep
# 12904   4077     0.0     VOLKSWAGEN      Golf        1997    Hatchback
# 15364  10036     0.0           OPEL    Meriva        2006    Universal
# 15393  15681     0.0         TOYOTA     Prius        2008        Sedan
# 16586  14113     0.0            BMW       328        2007        Sedan
# 17206   2822     0.0           FORD    Mondeo        1996  Goods wagon
# 17582   4234     0.0  MERCEDES-BENZ     E 200        2001        Sedan
# 18477  10976     0.0  MERCEDES-BENZ     E 270        2002        Sedan
# 19167  18817  1995.0           FORD   Transit        2003     Microbus
# 19199   3763     0.0  MERCEDES-BENZ     C 180        1995        Sedan
#
#       Leather interior Fuel type  Engine volume Aspiration       Mileage  \
# 985                 No       CNG            1.6    Natural  7.777778e+08
# 1146               Yes    Petrol            2.5    Natural  7.777787e+06
# 1404                No    Petrol            2.8    Natural  5.555666e+07
# 1892                No    Petrol            1.8    Natural  1.111111e+07
# 2278                No    Petrol            1.6    Natural  2.147484e+09
# 2512               Yes    Petrol            4.4    Natural  7.789999e+06
# 4823                No    Petrol            1.8    Natural  1.264885e+07
# 5456                No       CNG            3.3    Natural  1.000000e+09
# 6157                No       CNG            1.8    Natural  2.147484e+09
# 7000                No    Diesel            3.5    Natural  7.563145e+06
# 7429                No    Diesel            2.3    Natural  5.555551e+06
# 7724                No    Petrol            1.2    Natural  1.234568e+09
# 8824                No    Petrol            1.5    Natural  1.806544e+07
# 8858                No    Diesel            2.5    Natural  1.111111e+07
# 9330                No    Petrol            2.0      Turbo  6.768388e+06
# 9542               Yes    Petrol            2.0    Natural  2.000000e+07
# 10667               No       CNG            1.5    Natural  1.000000e+09
# 11144               No       CNG            2.0    Natural  5.800889e+07
# 11266               No    Diesel            2.5    Natural  5.451812e+06
# 11430               No    Petrol            1.6    Natural  1.111111e+07
# 11472               No    Petrol            1.3    Natural  2.300000e+07
# 11901               No    Petrol            2.0    Natural  2.147484e+09
# 12591               No       CNG            1.8    Natural  1.000000e+09
# 12734              Yes       CNG            2.4    Natural  2.147484e+09
# 12904               No       CNG            1.8    Natural  1.000000e+09
# 15364               No    Petrol            1.6    Natural  2.222222e+08
# 15393               No    Petrol            2.0    Natural  2.147484e+09
# 16586              Yes    Petrol            3.0    Natural  1.000000e+09
# 17206               No       CNG            1.8    Natural  4.000000e+07
# 17582              Yes       CNG            2.6    Natural  1.777778e+09
# 18477              Yes    Diesel            2.7      Turbo  1.111111e+08
# 19167               No    Diesel            2.4      Turbo  2.147484e+09
# 19199               No    Petrol            1.8    Natural  1.111111e+09
#
#        Cylinders Gear box type Drive wheels      Doors             Wheel  \
# 985            4     Automatic        Front          4        Left wheel
# 1146           6        Manual         Rear          4        Left wheel
# 1404           6        Manual         Rear          4        Left wheel
# 1892           4        Manual         Rear          4        Left wheel
# 2278           4        Manual        Front          4        Left wheel
# 2512           6     Automatic         Rear          4        Left wheel
# 4823           4        Manual          4x4          2        Left wheel
# 5456           6     Tiptronic          4x4          4        Left wheel
# 6157           4        Manual         Rear          4        Left wheel
# 7000           4        Manual         Rear          4        Left wheel
# 7429           4        Manual        Front          2        Left wheel
# 7724           4        Manual        Front          4        Left wheel
# 8824           4     Tiptronic        Front          4  Right-hand drive
# 8858           4        Manual         Rear          2        Left wheel
# 9330           4     Automatic        Front  5 or more        Left wheel
# 9542           4     Tiptronic          4x4          4  Right-hand drive
# 10667          4     Automatic          4x4          4  Right-hand drive
# 11144          4        Manual         Rear          4        Left wheel
# 11266          6        Manual         Rear          4        Left wheel
# 11430          4     Automatic        Front          4        Left wheel
# 11472          4        Manual          4x4          4  Right-hand drive
# 11901          4     Tiptronic          4x4          4  Right-hand drive
# 12591          4        Manual        Front          4        Left wheel
# 12734          4        Manual          4x4          4        Left wheel
# 12904          4        Manual        Front          4        Left wheel
# 15364          4     Tiptronic        Front          4        Left wheel
# 15393          4     Automatic        Front          4        Left wheel
# 16586          6     Tiptronic         Rear          4        Left wheel
# 17206          4        Manual        Front          4        Left wheel
# 17582          6     Tiptronic         Rear          4  Right-hand drive
# 18477          6     Tiptronic         Rear          4        Left wheel
# 19167          4        Manual        Front          2        Left wheel
# 19199          5        Manual         Rear          4  Right-hand drive
#
#                Color  Airbags
# 985            Beige        2
# 1146          Silver       10
# 1404          Silver        6
# 1892          Silver        2
# 2278           Black        4
# 2512           Brown        0
# 4823           Green        0
# 5456           Black        8
# 6157            Blue        5
# 7000          Yellow        2
# 7429           White        1
# 7724          Silver        2
# 8824           Black        5
# 8858           White        0
# 9330          Silver        4
# 9542           Black        3
# 10667          Black        0
# 11144           Blue        2
# 11266          White        2
# 11430          White        2
# 11472         Silver        7
# 11901          White       12
# 12591          Green        4
# 12734          Black       10
# 12904  Carnelian red        0
# 15364         Silver        6
# 15393           Blue        0
# 16586         Silver       16
# 17206          Green        4
# 17582          Black       10
# 18477         Silver        6
# 19167          White        2
# 19199          Green        2

# %%
high_mileage_indeces = Non_low_price_cars[Non_low_price_cars['Mileage']>1000000].index
cars = Non_low_price_cars.drop(index=high_mileage_indeces).reset_index(drop=True)
cars
# Out:
#        Price    Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399.0          LEXUS   RX 450        2010       Jeep
# 1      16621  1018.0      CHEVROLET  Equinox        2011       Jeep
# 2       8467     0.0          HONDA      FIT        2006  Hatchback
# 3       3607   862.0           FORD   Escape        2011       Jeep
# 4      11726   446.0          HONDA      FIT        2014  Hatchback
# ...      ...     ...            ...      ...         ...        ...
# 16586   5802  1055.0  MERCEDES-BENZ    E 350        2013      Sedan
# 16587   8467     0.0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 16588  15681   831.0        HYUNDAI   Sonata        2011      Sedan
# 16589  26108   836.0        HYUNDAI   Tucson        2010       Jeep
# 16590   5331  1288.0      CHEVROLET  Captiva        2007       Jeep
#
#       Leather interior Fuel type  Engine volume Aspiration   Mileage  \
# 0                  Yes    Hybrid            3.5    Natural  186005.0
# 1                   No    Petrol            3.0    Natural  192000.0
# 2                   No    Petrol            1.3    Natural  200000.0
# 3                  Yes    Hybrid            2.5    Natural  168966.0
# 4                  Yes    Petrol            1.3    Natural   91901.0
# ...                ...       ...            ...        ...       ...
# 16586              Yes    Diesel            3.5    Natural  107800.0
# 16587              Yes       CNG            2.0      Turbo  300000.0
# 16588              Yes    Petrol            2.4    Natural  161600.0
# 16589              Yes    Diesel            2.0    Natural  116365.0
# 16590              Yes    Diesel            2.0    Natural   51258.0
#
#        Cylinders Gear box type Drive wheels Doors             Wheel   Color  \
# 0              6     Automatic          4x4     4        Left wheel  Silver
# 1              6     Tiptronic          4x4     4        Left wheel   Black
# 2              4      Variator        Front     4  Right-hand drive   Black
# 3              4     Automatic          4x4     4        Left wheel   White
# 4              4     Automatic        Front     4        Left wheel  Silver
# ...          ...           ...          ...   ...               ...     ...
# 16586          6     Automatic         Rear     4        Left wheel    Grey
# 16587          4        Manual         Rear     2        Left wheel  Silver
# 16588          4     Tiptronic        Front     4        Left wheel     Red
# 16589          4     Automatic        Front     4        Left wheel    Grey
# 16590          4     Automatic        Front     4        Left wheel   Black
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 16586       12
# 16587        5
# 16588        8
# 16589        4
# 16590        4
#
# [16591 rows x 18 columns]

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(cars["Price"], ax=ax_box)
sns.histplot(data=cars, x="Price", ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

f.suptitle('Car Price Distribution Plot')

plt.show();

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(cars["Levy"], ax=ax_box)
sns.histplot(data=cars, x="Levy", ax=ax_hist,bins=60)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

f.suptitle('Car Levy Distribution Plot')

plt.show();

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(cars["Mileage"], ax=ax_box)
sns.histplot(data=cars, x="Mileage", ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

f.suptitle('Car Mileage Distribution Plot')

plt.show();

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(cars["Engine volume"], ax=ax_box)
sns.histplot(data=cars, x="Engine volume", ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

f.suptitle('Car Engine volume Distribution Plot')

plt.show();

print(cars['Engine volume'].describe())
# Out:
# count    16591.000000
# mean         2.265499
# std          0.845310
# min          0.000000
# 25%          1.800000
# 50%          2.000000
# 75%          2.500000
# max         20.000000
# Name: Engine volume, dtype: float64

# %%
cars[(cars['Engine volume']<0.7)|(cars['Engine volume']>7)]
# Out:
#         Price    Levy   Manufacturer         Model  Prod. year   Category  \
# 140      1300     0.0           AUDI            50        2018      Coupe
# 602      8154     0.0     MITSUBISHI       Airtrek        2002       Jeep
# 1350     1333   289.0           FORD        Escape        2008       Jeep
# 1719    53941    87.0          TESLA       Model X        2018      Sedan
# 1842     1333   289.0           FORD        Escape        2008       Jeep
# 2014    10036  5603.0        HYUNDAI        Sonata        2014      Sedan
# 2048     2500     0.0            VAZ          2106        1988      Sedan
# 2657     2430    87.0  MERCEDES-BENZ         C 250        2013      Coupe
# 2682     2666   155.0     VOLKSWAGEN           GTI        2015  Hatchback
# 3018    27356    87.0        HYUNDAI       Elantra        2016      Sedan
# 3803     4704     0.0  MERCEDES-BENZ         Smart        1999      Sedan
# 3855     3293   155.0     VOLKSWAGEN         Jetta        2015      Sedan
# 4032     6272     0.0  MERCEDES-BENZ         Smart        2001      Coupe
# 4138    17663    87.0         TOYOTA          Aqua        2012  Hatchback
# 4364     8311     0.0         SUZUKI         CERVO        2010  Universal
# 4619     7840  5877.0  MERCEDES-BENZ       CLK 430        2005  Cabriolet
# 4839     1000     0.0          HONDA       Element        2012      Sedan
# 4907     2437     0.0            VAZ          2106        1974      Sedan
# 6051    17663    87.0         TOYOTA          Aqua        2012  Hatchback
# 6276     2509   167.0     VOLKSWAGEN           Eos        2016      Sedan
# 6277     3000     0.0            VAZ          2107        1990      Sedan
# 6612    47076    87.0      SSANGYONG        REXTON        2016       Jeep
# 7096     4547   155.0     VOLKSWAGEN      Scirocco        2015      Sedan
# 7396     2437     0.0            VAZ          2106        1974      Sedan
# 9149    12231    87.0         TOYOTA         Prius        2010  Hatchback
# 9265     8624   175.0         TOYOTA          Vitz        2011  Hatchback
# 9316     1333   289.0           FORD        Escape        2008       Jeep
# 10746    8781     0.0  MERCEDES-BENZ         E 320        1999      Sedan
# 11164    2666   115.0         NISSAN          Leaf        2013       Jeep
# 11525  163077     0.0            BMW  M6 Gran cupe        2014      Sedan
# 11792    3293   155.0     VOLKSWAGEN         Jetta        2015      Sedan
# 12087    1333   155.0     VOLKSWAGEN        Passat        2015      Sedan
# 12290    2117   155.0     VOLKSWAGEN           GTI        2015  Hatchback
# 12924    6272     0.0          MAZDA         Demio        2003  Hatchback
# 13808    1333   289.0           FORD        Escape        2008       Jeep
# 14506    3136     0.0  MERCEDES-BENZ         Smart        2002      Coupe
# 15312   10036  5603.0        HYUNDAI        Sonata        2014      Sedan
# 16003    1333   289.0           FORD        Escape        2008       Jeep
#
#       Leather interior Fuel type  Engine volume Aspiration   Mileage  \
# 140                Yes    Petrol            0.5    Natural    4000.0
# 602                 No       LPG            0.2      Turbo   18800.0
# 1350               Yes    Hybrid            0.4    Natural  349288.0
# 1719               Yes    Petrol            0.0    Natural   81907.0
# 1842               Yes    Hybrid            0.4    Natural  349288.0
# 2014               Yes       LPG           20.0    Natural  333686.0
# 2048                No    Petrol            0.3    Natural       0.0
# 2657               Yes    Petrol            0.0    Natural  121600.0
# 2682               Yes    Petrol            0.2    Natural  104618.0
# 3018               Yes       LPG            0.0    Natural   65004.0
# 3803                No    Petrol            0.6      Turbo  142000.0
# 3855               Yes    Diesel            0.2    Natural  119394.0
# 4032                No    Petrol            0.6      Turbo  126000.0
# 4138               Yes    Petrol            0.0    Natural  118000.0
# 4364                No    Petrol            0.6    Natural  101000.0
# 4619                No    Petrol            7.3    Natural  156470.0
# 4839                No    Petrol            0.1    Natural    5000.0
# 4907                No    Petrol            0.6    Natural    5200.0
# 6051               Yes    Petrol            0.0    Natural  118000.0
# 6276               Yes    Petrol            0.2    Natural   57794.0
# 6277                No    Petrol            0.3    Natural   18101.0
# 6612               Yes    Diesel            0.0    Natural   73968.0
# 7096               Yes    Petrol            0.2    Natural  111965.0
# 7396                No    Petrol            0.6    Natural    5200.0
# 9149                No    Hybrid            0.0    Natural       0.0
# 9265                No    Petrol            0.1    Natural       0.0
# 9316               Yes    Hybrid            0.4    Natural  349288.0
# 10746              Yes    Petrol            0.6      Turbo  230000.0
# 11164              Yes    Petrol            0.1    Natural   99549.0
# 11525              Yes    Petrol            0.4      Turbo  100000.0
# 11792              Yes    Diesel            0.2    Natural  119394.0
# 12087              Yes    Diesel            0.2    Natural   88531.0
# 12290              Yes    Petrol            0.2    Natural  237930.0
# 12924               No    Petrol            0.3      Turbo    5000.0
# 13808              Yes    Hybrid            0.4    Natural  349288.0
# 14506               No    Petrol            0.6    Natural   10000.0
# 15312              Yes       LPG           20.0    Natural  333686.0
# 16003              Yes    Hybrid            0.4    Natural  349288.0
#
#        Cylinders Gear box type Drive wheels      Doors             Wheel  \
# 140            1     Tiptronic         Rear  5 or more  Right-hand drive
# 602            4     Tiptronic          4x4          4        Left wheel
# 1350           4     Automatic        Front          4        Left wheel
# 1719           6     Automatic          4x4          4        Left wheel
# 1842           4     Automatic        Front          4        Left wheel
# 2014           4     Automatic        Front          4        Left wheel
# 2048           4        Manual         Rear          4        Left wheel
# 2657           4     Automatic         Rear          4        Left wheel
# 2682           4     Automatic        Front          4        Left wheel
# 3018           4     Automatic        Front          4        Left wheel
# 3803           4     Tiptronic         Rear          2        Left wheel
# 3855           4     Automatic        Front          4        Left wheel
# 4032           3     Tiptronic         Rear          2        Left wheel
# 4138           4     Automatic        Front          4        Left wheel
# 4364           4        Manual          4x4          2  Right-hand drive
# 4619          12     Automatic         Rear          4        Left wheel
# 4839           1     Automatic         Rear          4        Left wheel
# 4907           1        Manual         Rear          2        Left wheel
# 6051           4     Automatic        Front          4        Left wheel
# 6276           4     Automatic        Front          4        Left wheel
# 6277           4        Manual         Rear          4        Left wheel
# 6612           4     Automatic        Front          4        Left wheel
# 7096           4     Automatic        Front          4        Left wheel
# 7396           1        Manual         Rear          2        Left wheel
# 9149           4     Automatic        Front          4        Left wheel
# 9265           3     Automatic        Front          4  Right-hand drive
# 9316           4     Automatic        Front          4        Left wheel
# 10746          6     Automatic         Rear          4        Left wheel
# 11164          1     Automatic        Front          4        Left wheel
# 11525          8     Automatic         Rear          4        Left wheel
# 11792          4     Automatic        Front          4        Left wheel
# 12087          4     Automatic        Front          4        Left wheel
# 12290          4     Automatic        Front          4        Left wheel
# 12924          4     Automatic          4x4          4  Right-hand drive
# 13808          4     Automatic        Front          4        Left wheel
# 14506          4     Tiptronic         Rear          2        Left wheel
# 15312          4     Automatic        Front          4        Left wheel
# 16003          4     Automatic        Front          4        Left wheel
#
#         Color  Airbags
# 140      Blue        0
# 602     Black        2
# 1350     Blue        0
# 1719   Silver       12
# 1842     Blue        0
# 2014   Silver        4
# 2048   Yellow        0
# 2657    White       12
# 2682    White       12
# 3018    White        4
# 3803    Black        2
# 3855    Black       12
# 4032   Silver        6
# 4138     Grey        4
# 4364    White        2
# 4619    Black       12
# 4839    Black        0
# 4907    White       10
# 6051     Grey        4
# 6276    White       12
# 6277    White        0
# 6612    Black        4
# 7096    Black       12
# 7396    White       10
# 9149   Golden        0
# 9265    Black        2
# 9316     Blue        0
# 10746    Blue        8
# 11164   White        0
# 11525   Black       12
# 11792   Black       12
# 12087     Red       12
# 12290   White       12
# 12924     Red        4
# 13808    Blue        0
# 14506    Blue        2
# 15312  Silver        4
# 16003    Blue        0

# %% [markdown]
# ##### Having that the smallest car engines in the market are around  0.3 L and any record having engine volumn less than 0.5 L is incorrect, we'll drop any record having engine volum less than 0.6L.
#
#
# ##### Similarly, records with engine volumn greater than 7 L are incorrect. I'll also get rid of them.

# %%
index_to_drop_EV =  cars[(cars['Engine volume']<0.6) | (cars['Engine volume']>7)].index

# %%
cars.drop(index=index_to_drop_EV, inplace=True)

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(cars["Engine volume"], ax=ax_box)
sns.histplot(data=cars, x="Engine volume", ax=ax_hist,bins=30)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')

f.suptitle('Car Engine volume Distribution Plot')

plt.show();

print(cars['Engine volume'].describe())
# Out:
# count    16560.000000
# mean         2.266540
# std          0.818009
# min          0.600000
# 25%          1.800000
# 50%          2.000000
# 75%          2.500000
# max          6.800000
# Name: Engine volume, dtype: float64

# %%
cars[cars['Cylinders']>8]
# Out:
#         Price     Levy   Manufacturer             Model  Prod. year  \
# 94      11917  11714.0  MERCEDES-BENZ         E 500 AMG        2003
# 266     22894      0.0         NISSAN        Pathfinder        2010
# 386     11604    993.0           OPEL             Astra        2006
# 619     81539   1360.0          LEXUS            GX 460        2013
# 703      7997    308.0         TOYOTA        Prius 2014        2014
# 712     30000      0.0         NISSAN           X-Trail        2018
# 1253    25716      0.0         TOYOTA      Prius plugin        2012
# 1636     7000      0.0          HONDA          Fit Aria        2003
# 1787    31988      0.0  MERCEDES-BENZ            ML 350        2010
# 2359   172486      0.0         TOYOTA      Land Cruiser        2018
# 2522     2800      0.0            VAZ              2107        1999
# 2558    45473      0.0            BMW          M5 Japan        2006
# 2726    27911   1172.0          LEXUS            RX 350        2011
# 3778    21012      0.0            KIA          Optima X        2012
# 3920    30734      0.0            BMW                X5        2008
# 4139    11917      0.0  MERCEDES-BENZ            ML 320        2003
# 4227   121524   3057.0  MERCEDES-BENZ        CLS 55 AMG        2019
# 4262    45000   2606.0            BMW                M5        2008
# 5638    18817    779.0     VOLKSWAGEN            Passat        2013
# 5909    21953      0.0        HYUNDAI           Elantra        2016
# 6169    47042      0.0            BMW                M5        2010
# 6557    50178      0.0            BMW               550        2007
# 6614    24000    919.0            BMW                X5        2012
# 6704    22894      0.0         TOYOTA             Prius        2014
# 7034   114154   1017.0            BMW               530        2017
# 7202    15681    966.0      CHEVROLET           Lacetti        2009
# 7810    14113      0.0           AUDI                A6        2006
# 7856    31988   3015.0        FERRARI               F50        2017
# 8443    14113      0.0            BMW                X5        2004
# 9028    56450      0.0     LAND ROVER  Land Rover Sport        2012
# 9180    16308    751.0            KIA         Optima EX        2013
# 9350    27598    639.0     VOLKSWAGEN            Tiguan        2014
# 9435    65545   1079.0  MERCEDES-BENZ           GLC 300        2018
# 10240   14113   2874.0           FORD      Explorer XLT        2006
# 10839   39829      0.0            BMW                X6        2009
# 11207   49864    917.0          LEXUS            ES 300        2013
# 11505   89379      0.0  MERCEDES-BENZ            ML 300        2015
# 12081   38574      0.0            BMW                M5        2006
# 12166   42337    639.0            BMW               528        2014
# 12208   39201      0.0  MERCEDES-BENZ             E 550        2010
# 12714   58018   1017.0            BMW                X1        2017
# 13298  153669   1823.0            BMW                M3        2018
# 13475   37633      0.0            BMW                M6        2007
# 13708   13485    919.0      CHEVROLET           Captiva        2012
# 13821   28225    640.0            BMW                X1        2013
# 14138   19757      0.0     VOLKSWAGEN           Touareg        2003
# 14222    7213      0.0           OPEL             Combo        2001
# 15264   40769      0.0          LEXUS            ES 300        2013
# 15276    9408      0.0  MERCEDES-BENZ             S 600        2000
# 15505   14113      0.0  MERCEDES-BENZ               320        2003
# 16350   14740  11706.0  MERCEDES-BENZ         E 500 AVG        2005
# 16374   11917  11714.0  MERCEDES-BENZ             E 500        2003
# 16430   14113   4860.0  MERCEDES-BENZ            CL 600        2002
#
#           Category Leather interior       Fuel type  Engine volume Aspiration  \
# 94           Sedan              Yes          Petrol            5.0    Natural
# 266          Sedan               No          Petrol            4.0    Natural
# 386    Goods wagon               No          Diesel            1.3      Turbo
# 619           Jeep              Yes          Petrol            4.6    Natural
# 703          Sedan              Yes          Hybrid            1.8    Natural
# 712         Pickup              Yes          Petrol            2.5    Natural
# 1253     Hatchback               No  Plug-in Hybrid            1.8    Natural
# 1636     Hatchback               No          Petrol            1.5      Turbo
# 1787          Jeep              Yes          Petrol            3.5    Natural
# 2359          Jeep              Yes          Diesel            4.7      Turbo
# 2522         Sedan               No          Petrol            1.6    Natural
# 2558         Sedan              Yes          Petrol            5.0    Natural
# 2726          Jeep              Yes          Petrol            3.5    Natural
# 3778         Sedan              Yes          Petrol            2.0      Turbo
# 3920          Jeep              Yes          Petrol            4.8    Natural
# 4139          Jeep              Yes          Petrol            3.2    Natural
# 4227         Sedan              Yes          Petrol            6.0    Natural
# 4262         Sedan              Yes          Petrol            5.0    Natural
# 5638         Sedan              Yes          Petrol            2.5    Natural
# 5909         Sedan              Yes          Petrol            1.8    Natural
# 6169         Sedan              Yes          Petrol            5.0    Natural
# 6557         Sedan              Yes          Petrol            5.0    Natural
# 6614          Jeep              Yes          Petrol            3.0      Turbo
# 6704         Sedan              Yes          Hybrid            1.8      Turbo
# 7034         Sedan              Yes          Petrol            2.0      Turbo
# 7202         Sedan              Yes          Diesel            2.0    Natural
# 7810         Sedan              Yes          Petrol            3.2    Natural
# 7856         Coupe              Yes          Petrol            6.3    Natural
# 8443          Jeep              Yes          Petrol            4.8    Natural
# 9028          Jeep              Yes          Petrol            5.0    Natural
# 9180         Sedan              Yes          Petrol            2.4    Natural
# 9350          Jeep              Yes          Petrol            2.0      Turbo
# 9435          Jeep              Yes          Petrol            2.0      Turbo
# 10240         Jeep              Yes          Petrol            4.0    Natural
# 10839         Jeep              Yes          Petrol            3.5      Turbo
# 11207        Sedan              Yes          Hybrid            3.0    Natural
# 11505         Jeep              Yes          Petrol            3.0      Turbo
# 12081        Sedan              Yes          Petrol            5.0    Natural
# 12166        Sedan              Yes          Petrol            2.0      Turbo
# 12208        Coupe              Yes          Petrol            5.5      Turbo
# 12714        Sedan              Yes          Petrol            2.0      Turbo
# 13298        Sedan              Yes          Petrol            3.5      Turbo
# 13475        Coupe              Yes          Petrol            5.0    Natural
# 13708         Jeep              Yes          Petrol            3.0    Natural
# 13821         Jeep              Yes          Petrol            2.0    Natural
# 14138         Jeep              Yes          Diesel            5.0      Turbo
# 14222  Goods wagon               No          Diesel            1.7      Turbo
# 15264        Sedan              Yes          Hybrid            2.5    Natural
# 15276        Sedan              Yes          Petrol            5.8    Natural
# 15505        Sedan              Yes             CNG            3.2    Natural
# 16350        Sedan              Yes          Petrol            5.0    Natural
# 16374        Sedan              Yes          Petrol            5.0    Natural
# 16430        Coupe              Yes          Petrol            6.0    Natural
#
#         Mileage  Cylinders Gear box type Drive wheels      Doors  \
# 94     150000.0         12     Tiptronic         Rear          4
# 266    109100.0         12     Automatic          4x4          4
# 386     27000.0         16        Manual        Front          4
# 619     76800.0         12     Tiptronic          4x4          4
# 703         0.0         12     Tiptronic        Front          4
# 712     18794.0         12     Automatic          4x4  5 or more
# 1253    75000.0         12     Automatic        Front          4
# 1636   140203.0         16     Automatic        Front          4
# 1787   124000.0         12     Tiptronic          4x4          4
# 2359    13000.0         12     Automatic          4x4          4
# 2522    10000.0          9        Manual          4x4          2
# 2558    97000.0         10        Manual         Rear          4
# 2726   900000.0         12     Tiptronic        Front          4
# 3778   155000.0         12     Tiptronic        Front          4
# 3920   230000.0         12     Tiptronic          4x4          4
# 4139        0.0         10     Automatic          4x4          4
# 4227        0.0         12     Automatic         Rear          4
# 4262   113473.0         10     Tiptronic         Rear          4
# 5638   115000.0         10     Automatic        Front          4
# 5909    69000.0         16     Automatic        Front          4
# 6169    94000.0         10        Manual         Rear          4
# 6557   158400.0         10     Tiptronic         Rear          4
# 6614   147718.0         12     Automatic          4x4          4
# 6704    37000.0         12     Automatic         Rear          4
# 7034    42000.0         12     Tiptronic         Rear          4
# 7202     6500.0         14     Automatic        Front          4
# 7810   260000.0         12     Tiptronic        Front          4
# 7856   419200.0         12     Automatic         Rear          2
# 8443   206000.0         12     Tiptronic          4x4          4
# 9028   165000.0         12     Tiptronic          4x4          4
# 9180    92000.0         12     Tiptronic        Front          4
# 9350   113000.0         12     Tiptronic          4x4          4
# 9435    12000.0         12     Tiptronic         Rear          4
# 10240  117000.0         12     Automatic          4x4          4
# 10839  152000.0         16     Tiptronic          4x4          4
# 11207  100000.0         10     Automatic        Front          4
# 11505   66000.0         12     Tiptronic          4x4          4
# 12081   70000.0         10     Tiptronic         Rear          4
# 12166   10000.0         12     Automatic         Rear          4
# 12208   67000.0         12     Tiptronic         Rear          2
# 12714   31000.0         12     Automatic          4x4          4
# 13298    3900.0         12        Manual         Rear          4
# 13475  187500.0         10     Tiptronic         Rear          2
# 13708  155000.0         10     Tiptronic          4x4          4
# 13821  108000.0         12     Tiptronic        Front          4
# 14138  170000.0         10     Automatic         Rear          4
# 14222  242701.0         16        Manual        Front          2
# 15264    8700.0         12     Tiptronic        Front          4
# 15276  112000.0         12     Tiptronic         Rear          4
# 15505   37000.0         12     Tiptronic         Rear          4
# 16350   56000.0         12     Tiptronic         Rear          4
# 16374  150000.0         12     Tiptronic         Rear          4
# 16430  127000.0         12     Tiptronic         Rear          2
#
#                   Wheel          Color  Airbags
# 94     Right-hand drive          White       12
# 266          Left wheel           Blue       12
# 386          Left wheel          Black        8
# 619          Left wheel          Black        0
# 703          Left wheel          Black       12
# 712          Left wheel          Black       12
# 1253         Left wheel         Silver       10
# 1636   Right-hand drive         Silver        2
# 1787         Left wheel          Black       12
# 2359         Left wheel          White       16
# 2522         Left wheel          White        6
# 2558         Left wheel           Blue       10
# 2726         Left wheel          Black       12
# 3778         Left wheel  Carnelian red       12
# 3920         Left wheel          Black       12
# 4139         Left wheel           Blue       10
# 4227         Left wheel          Black       12
# 4262         Left wheel          White       10
# 5638         Left wheel         Silver       12
# 5909         Left wheel         Silver       16
# 6169         Left wheel          Black       12
# 6557         Left wheel          Black       12
# 6614         Left wheel           Grey       12
# 6704         Left wheel            Red        0
# 7034         Left wheel          White       12
# 7202         Left wheel          White        8
# 7810         Left wheel         Silver       12
# 7856         Left wheel         Silver       12
# 8443         Left wheel           Blue        8
# 9028         Left wheel          Black        0
# 9180         Left wheel         Silver        8
# 9350         Left wheel          White       12
# 9435         Left wheel          Black       12
# 10240        Left wheel           Grey       12
# 10839        Left wheel           Grey       16
# 11207        Left wheel          Black       12
# 11505        Left wheel          Black       10
# 12081        Left wheel          Black       12
# 12166        Left wheel          White       12
# 12208        Left wheel          White       12
# 12714        Left wheel          Black       12
# 13298        Left wheel          Black       16
# 13475        Left wheel          Black       12
# 13708        Left wheel         Silver       10
# 13821        Left wheel          Black       12
# 14138        Left wheel           Grey        6
# 14222        Left wheel           Blue        2
# 15264        Left wheel          White       12
# 15276        Left wheel         Silver       12
# 15505        Left wheel         Silver       12
# 16350  Right-hand drive          Black       12
# 16374  Right-hand drive          White       12
# 16430        Left wheel         Silver       12

# %% [markdown]
# ##### As seen in the previous dataframe, records with number of cylinders greater than 8 are incorrect, so we'll not concider them.

# %%
indeces_to_drop = cars[cars['Cylinders']>8].index

# %%
cars.drop(index=indeces_to_drop,inplace=True)

# %%
cars.hist(bins=50);

# %% [markdown]
# ## So far, we have just done the data cleaning. We'll then proceed to see correlation and feature selection.

# %% [markdown]
# #### For that, we'll define a plotting function that will comprare pairwise.

# %%
import scipy
from scipy.stats.stats import pearsonr

def pairplot(x_axis,y_axis) :
    sns.pairplot(cars,x_vars=x_axis,y_vars=y_axis,height=4,aspect=1)
    plt.show()

# %%
Numerical = ['Levy','Prod. year','Engine volume','Mileage']
Categorical = ['Manufacturer','Model','Category','Leather interior','Fuel type','Aspiration',
               'Cylinders','Gear box type','Drive wheels','Doors','Wheel','Color','Airbags']

target = ['Price']

# %%
pairplot('Levy','Prod. year','Engine volume','Mileage','Price')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-8b0619ae9dd4> in <module>
# ----> 1 pairplot('Levy','Prod. year','Engine volume','Mileage','Price')
#
# TypeError: pairplot() takes 2 positional arguments but 5 were given

# %%
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_1, ax_2,ax_3,ax_4) = plt.subplots(nrows=2,ncols=2)
 
# assigning a graph to each ax
ax_1.plot(data=cars, x="Levy", y='Price')
ax_2.scatterplot(data=cars, x="Prod. year", y='Price')
ax_3.scatterplot(data=cars, x="Engine volume", y='Price')
ax_4.scatterplot(data=cars, x="Mileage", y='Price')
 

f.suptitle('Scatter plot between numeric varibales and Price')

plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-ed5644ccc639> in <module>
#       1 # creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
# ----> 2 f, (ax_1, ax_2,ax_3,ax_4) = plt.subplots(nrows=2,ncols=2)
#       3
#       4 # assigning a graph to each ax
#       5 ax_1.scatterplot(data=cars, x="Levy", y='Price')
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
sns.pairplot(cars,x_vars=['Levy','Prod. year','Engine volume','Mileage'],y_vars=['Price'],height=4,aspect=1,kind="scatter")
plt.show()

# %%
sns.scatterplot(data=cars,x='Levy',y='Price');

# %%
from sklearn.model_selection import train_test_split
